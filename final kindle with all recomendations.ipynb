# %%
class Book:
    def __init__(self, title, author, genre):
        self.title = title
        self.author = author
        self.genre = genre

class User:
    def __init__(self, name):
        self.name = name
        self.reading_list = []
        self.history = []
        self.wish_list = []

    def add_to_reading_list(self, book):
        self.reading_list.append(book)

    def add_to_history(self, book):
        self.history.append(book)

    def add_to_wish_list(self, book):
        self.wish_list.append(book)

    def recommend_books(self, page_data):
        if page_data == "page-1":
            return self.reading_list
        elif page_data == "page-2":
            return self.history
        elif page_data == "page-3":
            # In a real application, you would fetch best sellers from a database or external API
            # For simplicity, I'll just return a list of best sellers here
            return [Book("Best Seller 1", "Author 1", "Fiction"), Book("Best Seller 2", "Author 2", "Non-Fiction")]
        elif page_data == "page-4":
            return self.wish_list
        else:
            return []

# Example usage
user1 = User("John")
book1 = Book("Python Programming", "Guido van Rossum", "Programming")
book2 = Book("Deep Learning", "Ian Goodfellow", "Artificial Intelligence")
book3 = Book("The Great Gatsby", "F. Scott Fitzgerald", "Classic")
book4 = Book("Clean Code", "Robert C. Martin", "Programming")

user1.add_to_reading_list(book1)
user1.add_to_reading_list(book2)
user1.add_to_history(book3)
user1.add_to_wish_list(book4)

# Page-1 Data: List of books user started reading and continue reading
print("Page-1 Data:")
for book in user1.recommend_books("page-1"):
    print(book.title)

# Page-2 Data: List of products based on user's history
print("\nPage-2 Data:")
for book in user1.recommend_books("page-2"):
    print(book.title)

# Page-3 Data: List of Best sellers
print("\nPage-3 Data:")
for book in user1.recommend_books("page-3"):
    print(book.title)

# Page-4 Data: Only Wish List
print("\nPage-4 Data:")
for book in user1.recommend_books("page-4"):
    print(book.title)

# %%
class Book:
    def __init__(self, title, author, genre):
        self.title = title
        self.author = author
        self.genre = genre

class User:
    def __init__(self, name):
        self.name = name
        self.reading_list = []
        self.history = []
        self.wish_list = []

    def add_to_reading_list(self, book):
        self.reading_list.append(book)

    def add_to_history(self, book):
        self.history.append(book)

    def add_to_wish_list(self, book):
        self.wish_list.append(book)

    def recommend_books(self, page_data):
        if page_data == "page-1":
            return self.reading_list
        elif page_data == "page-2":
            return self.history
        elif page_data == "page-3":
            # In a real application, you would fetch best sellers from a database or external API
            # For simplicity, I'll just return a list of best sellers here
            return [Book("Best Seller 1", "Author 1", "Fiction"), Book("Best Seller 2", "Author 2", "Non-Fiction")]
        elif page_data == "page-4":
            return self.wish_list
        else:
            return []

# Example usage
user1 = User("John")
book1 = Book("Python Programming", "Guido van Rossum", "Programming")
book2 = Book("Deep Learning", "Ian Goodfellow", "Artificial Intelligence")
book3 = Book("The Great Gatsby", "F. Scott Fitzgerald", "Classic")
book4 = Book("Clean Code", "Robert C. Martin", "Programming")

user1.add_to_reading_list(book1)
user1.add_to_reading_list(book2)
user1.add_to_history(book3)
user1.add_to_wish_list(book4)

# Page-1 Data: List of books user started reading and continue reading
print("Page-1 Data:")
for book in user1.recommend_books("page-1"):
    print(book.title)

# Page-2 Data: List of products based on user's history
print("\nPage-2 Data:")
for book in user1.recommend_books("page-2"):
    print(book.title)

# Page-3 Data: List of Best sellers
print("\nPage-3 Data:")
for book in user1.recommend_books("page-3"):
    print(book.title)

# Page-4 Data: Only Wish List
print("\nPage-4 Data:")
for book in user1.recommend_books("page-4"):
    print(book.title)

# %%
class Book:
    def __init__(self, title, author, genre):
        self.title = title
        self.author = author
        self.genre = genre

class User:
    def __init__(self, name):
        self.name = name
        self.reading_list = []
        self.history = []
        self.wish_list = []

    def add_to_reading_list(self, book):
        self.reading_list.append(book)

    def add_to_history(self, book):
        self.history.append(book)

    def add_to_wish_list(self, book):
        self.wish_list.append(book)

    def recommend_books(self, page_data):
        if page_data == "page-1":
            return self.reading_list
        elif page_data == "page-2":
            return self.history
        elif page_data == "page-3":
            # In a real application, you would fetch best sellers from a database or external API
            # For simplicity, I'll just return a list of best sellers here
            return [Book("Best Seller 1", "Author 1", "Fiction"), Book("Best Seller 2", "Author 2", "Non-Fiction")]
        elif page_data == "page-4":
            return self.wish_list
        else:
            return []

# Example usage
user1 = User("John")
book1 = Book("Python Programming", "Guido van Rossum", "Programming")
book2 = Book("Deep Learning", "Ian Goodfellow", "Artificial Intelligence")
book3 = Book("The Great Gatsby", "F. Scott Fitzgerald", "Classic")
book4 = Book("Clean Code", "Robert C. Martin", "Programming")

user1.add_to_reading_list(book1)
user1.add_to_reading_list(book2)
user1.add_to_history(book3)
user1.add_to_wish_list(book4)



# Page-1 Data: List of books user started reading and continue reading
print("Page-1 Data:user started reading and continue reading")
for i, book in enumerate(user1.recommend_books("page-1"), 1):
    print(f"{i}. {book.title}")

# Page-2 Data: List of products based on user's history
print("\nPage-2 Data:user's history")
for i, book in enumerate(user1.recommend_books("page-2"), 1):
    print(f"{i}. {book.title}")

# Page-3 Data: List of Best sellers
print("\nPage-3 Data:List of Best sellers")
for i, book in enumerate(user1.recommend_books("page-3"), 1):
    print(f"{i}. {book.title}")

# Page-4 Data: Only Wish List
print("\nPage-4 Data:Wish List")
for i, book in enumerate(user1.recommend_books("page-4"), 1):
    print(f"{i}. {book.title}")
# Out:
# Page-1 Data:user started reading and continue reading
# Python Programming
# Deep Learning
#
# Page-2 Data:user's history
# The Great Gatsby
#
# Page-3 Data:List of Best sellers
# Best Seller 1
# Best Seller 2
#
# Page-4 Data:Wish List
# Clean Code
# Page-1 Data:user started reading and continue reading
# 1. Python Programming
# 2. Deep Learning
#
# Page-2 Data:user's history
# 1. The Great Gatsby
#
# Page-3 Data:List of Best sellers
# 1. Best Seller 1
# 2. Best Seller 2
#
# Page-4 Data:Wish List
# 1. Clean Code
